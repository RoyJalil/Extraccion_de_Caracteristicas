# %% [markdown]
# <a href="https://colab.research.google.com/github/RoyJalil/Extraccion_de_Caracteristicas/blob/main/Extraccion_de_Caracteristicas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .xlsx sin indice
Micro_Retailer= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Verificamos información del DataFrame
Micro_Retailer.info()

# %%
#Imprimo los primeros 5 registro del dataframe
Micro_Retailer.head(2)

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(Micro_Retailer)

# %%
#Filtro por columnas
filtro20=Micro_Retailer.iloc[ : , [1,2,3,8,9,15,23,25,27,30,32,34,35,36,48,55,66,68,75,81]]  #columnas no consecutivas
filtro20

# %%
#Corroboramos valores nulos
valores_nulos=filtro20.isnull().sum()
valores_nulos
# Out:
# _title                                        0
# _server_updated_at                            0
# _updated_by                                   0
# 229_store_picture                             0
# 232_type_of_store                             0
# 184_store_devices                             0
# 5_change_store_space_last_year                0
# 20_reviews_finances_monthly                   0
# 18_sales_records                              0
# 19_tax_id                                     0
# 310_burnout                                   0
# 186_internet_connection                       0
# 210_sales_channels                            0
# 189_payment_methods                           0
# 33_credit_to_customers                        0
# 60_services                                  10
# 311_topups                                   10
# 313_home_deliveries                          10
# 43_willingness_share_sales_data_suppliers    10
# 278_credit_interest                          11
# dtype: int64

# %%
filtro20=filtro20.fillna(method="bfill")
# Out:
# <ipython-input-70-012758501d77>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   filtro20=filtro20.fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=filtro20.isnull().sum()
valores_nulos
# Out:
# _title                                       0
# _server_updated_at                           0
# _updated_by                                  0
# 229_store_picture                            0
# 232_type_of_store                            0
# 184_store_devices                            0
# 5_change_store_space_last_year               0
# 20_reviews_finances_monthly                  0
# 18_sales_records                             0
# 19_tax_id                                    0
# 310_burnout                                  0
# 186_internet_connection                      0
# 210_sales_channels                           0
# 189_payment_methods                          0
# 33_credit_to_customers                       0
# 60_services                                  0
# 311_topups                                   0
# 313_home_deliveries                          0
# 43_willingness_share_sales_data_suppliers    0
# 278_credit_interest                          0
# dtype: int64

# %%
filtro20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 20 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   _title                                     171 non-null    object
#  1   _server_updated_at                         171 non-null    object
#  2   _updated_by                                171 non-null    object
#  3   229_store_picture                          171 non-null    object
#  4   232_type_of_store                          171 non-null    object
#  5   184_store_devices                          171 non-null    object
#  6   5_change_store_space_last_year             171 non-null    object
#  7   20_reviews_finances_monthly                171 non-null    object
#  8   18_sales_records                           171 non-null    object
#  9   19_tax_id                                  171 non-null    object
#  10  310_burnout                                171 non-null    object
#  11  186_internet_connection                    171 non-null    object
#  12  210_sales_channels                         171 non-null    object
#  13  189_payment_methods                        171 non-null    object
#  14  33_credit_to_customers                     171 non-null    object
#  15  60_services                                171 non-null    object
#  16  311_topups                                 171 non-null    object
#  17  313_home_deliveries                        171 non-null    object
#  18  43_willingness_share_sales_data_suppliers  171 non-null    object
#  19  278_credit_interest                        171 non-null    object
# dtypes: object(20)
# memory usage: 26.8+ KB

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(filtro20)

# %%
pd.options.display.max_columns = None

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['_title'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('_title')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['_server_updated_at'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('_server_updated_at')
Filtro_index1
#Realizamos grafico de área del dataframe filtrado
Filtro_index1.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='_server_updated_at'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['_updated_by'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('_updated_by')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['229_store_picture'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('229_store_picture')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('No. Fotos del Negocio')
plt.xlabel('Cantidad de fotografías')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['232_type_of_store'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('232_type_of_store')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['184_store_devices'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('184_store_devices')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['5_change_store_space_last_year'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('5_change_store_space_last_year')
Filtro_index1
#Realizamos grafico de área del dataframe filtrado
Filtro_index1.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='5_change_store_space_last_year'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['20_reviews_finances_monthly'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('20_reviews_finances_monthly')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['18_sales_records'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('18_sales_records')
Filtro_index1
#Realizamos grafico de barras del dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['19_tax_id'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('19_tax_id')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['310_burnout'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('310_burnout')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['186_internet_connection'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('186_internet_connection')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['210_sales_channels'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('210_sales_channels')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['189_payment_methods'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('189_payment_methods')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['33_credit_to_customers'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('33_credit_to_customers')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer["60_services"])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('60_services')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['311_topups'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('311_topups')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['313_home_deliveries'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('313_home_deliveries')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['43_willingness_share_sales_data_suppliers'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('43_willingness_share_sales_data_suppliers')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['278_credit_interest'])
table1
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]
Filtro1
#Ajusto el indice de mi dataframe
Filtro_index1= Filtro1.set_index('278_credit_interest')
Filtro_index1
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>
